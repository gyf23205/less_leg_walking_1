# %%
import json
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

LOSSES = ["loss", "loss_kae", "action_loss", "recon_loss", "state_loss", "latent_loss"]

session_id = "s20260818_094056"

target_task = [
    "Less-AnymalC-Jump-Direct-v1",
    "Less-AnymalC-Flat-Walking-Direct-v1",
    "Less-Leg-Flat-Walking-Direct-v1",
    "Less-AnymalC-Jump-Rough-Direct-v1",
    "Less-Leg-Rough-Walking-Direct-v1",
] # "Less-AnymalC-Rough-Walking-Direct-v1",

# FILES = "/home/joonwon/github/less_leg_walking_1.worktrees/origin-master/source/less_leg_walking_1/less_leg_walking_1/tasks/direct/less_leg_walking_1/KAEs/sessions/" + session_id + "/kae_logs/" + target_task + "_kae_history.csv"
# print("Reading files:", FILES)
# f = pd.read_csv(FILES)

# %%
for i in target_task:
    FILES = "/home/joonwon/github/less_leg_walking_1.worktrees/origin-master/source/less_leg_walking_1/less_leg_walking_1/tasks/direct/less_leg_walking_1/KAEs/sessions/" + session_id + "/kae_logs/" + i + "_kae_history.csv"
    f = pd.read_csv(FILES)
    f.plot(x="epoch", y="loss", label=i)
